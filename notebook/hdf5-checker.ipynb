# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py

# Open the file in read mode
import h5py

# Open the file
f = h5py.File('/content/drive/MyDrive/bitirme/dataset/phoenix2014.h5', 'r')

# Now f is accessible anywhere in this scope
print(f.keys())

#data = f['dataset1'][:]

# When you're done, close it manually
#f.close()
# Out:
# <KeysViewHDF5 ['dev', 'test', 'train']>

# %%
data = f['dev']

# %%
print(data.keys())
# Out:
# <KeysViewHDF5 ['01April_2010_Thursday_heute-6697', '01April_2010_Thursday_heute-6698', '01December_2011_Thursday_heute-3058', '01December_2011_Thursday_heute-3060', '01December_2011_Thursday_heute-3061', '01February_2011_Tuesday_heute-4637', '01February_2011_Tuesday_tagesschau-4975', '01February_2011_Tuesday_tagesschau-4976', '01July_2009_Wednesday_tagesschau-4555', '01July_2011_Friday_tagesschau-2763', '01July_2011_Friday_tagesschau-2765', '01July_2011_Friday_tagesschau-2766', '01June_2010_Tuesday_tagesschau-5002', '01March_2011_Tuesday_tagesschau-2209', '01March_2011_Tuesday_tagesschau-2210', '01March_2011_Tuesday_tagesschau-2211', '01May_2010_Saturday_tagesschau-7197', '01November_2010_Monday_tagesschau-140', '01October_2009_Thursday_tagesschau-417', '01October_2010_Friday_tagesschau-2691', '02December_2010_Thursday_heute-8444', '02December_2010_Thursday_heute-8445', '02December_2010_Thursday_tagesschau-3636', '02December_2010_Thursday_tagesschau-3637', '02December_2011_Friday_tag
# ...

# %%
import pickle

# %%
labels = None
with open(f'/content/drive/MyDrive/bitirme/dataset/val_labels.pkl', 'rb') as f:
    labels = pickle.load(f)

# %%
for row in labels:
  for val in row:
    if val != 1.0 and val != 0.0:
      print("invalid value: " + str(val))

# %%
print(len(labels))
# Out:
# 512

# %%
print(len(labels[0]))
# Out:
# 2409

# %%
import torch
tensor_labels = torch.tensor(labels, dtype=torch.float32)
# Out:
# <ipython-input-14-b28d9d3d2965>:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   tensor_labels = torch.tensor(labels, dtype=torch.float32)

# %%
type(tensor_labels[0])
# Out:
# torch.Tensor

# %%
type(tensor_labels)
# Out:
# torch.Tensor
